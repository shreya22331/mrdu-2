# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Arithematic Operators

# %%
# Addition

a = 10
b = 20
c = a + b
print(a+b)
# Out:
# 30

# %%
# Substract
a = 20.5
b = 19.7
c = a - b
print(c)
# Out:
# 0.8000000000000007

# %%
# Multiplication
a = 20
b = 30
c = a * b
print(c)
# Out:
# 600

# %%
# Division
a = 100
b = 6
c = a / b # 100/6
print(c)
# Out:
# 16.666666666666668

# %%
# Floor Division
a = 100
b = 6
c = a // b
print(c)
# Out:
# 16

# %%
# Modulo : Returns Remainder
a = 100
b = 6
c = a % b
print(c)
# Out:
# 4

# %%
# Exponential / Power
a = 2
b = 10
c = a ** b # 2^10
print(c)
# Out:
# 1024

# %%
#Addition
a = 2.5
b = 3.5
c = a+b
print(c)
# Out:
# 6.0

# %%
# int + int
a = 10
b = 20
c = a + b
print(c)
# Out:
# 30

# %%
# str + str
a = "Hello"
b = "world"
c  = a + b
print(c)
# Out:
# Helloworld

# %%
#int + str
a = 10
b = "Hello"
c = a + b
print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 #int + str
#       2 a = 10
#       3 b = "Hello"
# ----> 4 c = a + b
#       5 print(c)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#int * int
a = 10
b = 20
c = a * b
print(c)
# Out:
# 200

# %%
#str * str
a = "Hello"
b = "Shreya"
c = a * b
print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 #str * str
#       2 a = "Hello"
#       3 b = "Shreya"
# ----> 4 c = a * b
#       5 print(c)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
#int * str
a = 10
b = "Shreya"
c = a * b
print(c)
# Out:
# ShreyaShreyaShreyaShreyaShreyaShreyaShreyaShreyaShreyaShreya

# %%
l = 6
b = 5
c = l * b
print(c)
# Out:
# 30

# %%
l = 5
b = 4
c = 2(l + b)
print(c)
# Out:
# <>:3: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:3: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# C:\Users\Super Admin\AppData\Local\Temp\ipykernel_11200\2521502895.py:3: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   c = 2(l + b)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 l = 5
#       2 b = 4
# ----> 3 c = 2(l + b)
#       4 print(c)
#
# TypeError: 'int' object is not callable

# %%
l = 5
b = 4
c = 2*l+b
print(c)
# Out:
# 14

# %%
side = int(input("Enter the side of square: "))
area = side*side
print("The Area of square is:", area)
# Out:
# The Area of square is: 3136

# %%
kilometers = int(input("Enter the distance in kilometers: "))
meters = kilometers * 1000
print("The distance in meters is:", meters)
# Out:
# The distance in meters is: 8000

# %%
rupees = int(input("Enter the amount in rupees: "))
dollars = rupees / 80
print("The amount in dollars =" , dollars)
# Out:
# The amount in dollars = 0.625

# %%
# Out:
#   Cell In[11], line 2
#     what to repeat : mrdu
#          ^
# SyntaxError: invalid syntax
